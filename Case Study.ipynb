# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Read the dataset to the python environment.

# %%
filename='Downloads/cars_data.csv'
data=pd.read_csv(filename)
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# 0     User-friendly      Belgium        Antwerpen        51.247239
# 1         analyzing        China            Jinhu        33.025433
# 2          software        China             Gemo        30.916207
# 3        monitoring     Portugal  Queluz de Baixo        38.745168
# 4          Sharable       Latvia         Jaunpils        56.729980
# ...             ...          ...              ...              ...
# 9995       hardware     Pakistan  Chishtiān Mandi        29.919386
# 9996       Enhanced   Costa Rica          Ángeles        10.075000
# 9997     monitoring       Poland        Dąbrowice        52.311923
# 9998       cohesive  Philippines         Villasis        15.901640
# 9999      analyzing  Philippines            Basud        14.048167
#
#       Dealer Longitude    Color  New Car Purchase Date  Sale Price  Discount  \
# 0             4.440346   Yellow    False    19/07/2009    54806.14    0.2467
# 1           119.020584  Crimson    False    26/10/2015    51826.30    0.3147
# 2           121.677640    Khaki    False    28/03/2010    82929.14    0.5414
# 3            -9.267087     Puce    False    07/05/2008    56928.66    0.0850
# 4            23.016588   Yellow    False    01/06/2008    77201.26    0.1642
# ...                ...      ...      ...           ...         ...       ...
# 9995         73.074787     Pink    False    05/01/2020    58580.65    0.1611
# 9996        -84.241523     Puce    False    28/12/2005    75229.74    0.2691
# 9997         19.084965     Blue    False    08/03/2013    34755.44    0.2493
# 9998        120.587828     Teal     True    21/02/2008    98725.42    0.4654
# 9999        122.955697     Pink    False    16/12/2017    96769.78    0.5446
#
#       Resell Price  5-yr Depreciation  Top Speed  0-60 Time
# 0         33858.32               0.13      200.9       11.5
# 1          2989.28               0.02      158.5        8.8
# 2         35049.16               0.24      149.5       14.4
# 3          8236.15               0.20      153.3       11.5
# 4         32765.76               0.18      122.0       14.9
# ...            ...                ...        ...        ...
# 9995      42640.82               0.14      245.8        8.0
# 9996      21115.58               0.11      147.4       12.3
# 9997       2731.25               0.12      198.1       11.8
# 9998      18718.58               0.04      206.7       12.2
# 9999       4545.95               0.07      242.1        3.2
#
# [10000 rows x 20 columns]

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
data.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# Insights-
#
# There are no null values in the given data

# %% [markdown]
# # 3. Plot a bar graph of male vs female buyers participated in the sales.

# %% [markdown]
# 1.Bar Graph of male vs female buyers participated in the sales

# %%
Buyer = data['Buyer Gender'].value_counts().to_frame().reset_index()
Buyer
# Out:
#     index  Buyer Gender
# 0  Female          5052
# 1    Male          4948

# %%
plt.bar(Buyer['index'],Buyer['Buyer Gender'],color = ['red','blue'])
plt.title('Bar Graph of Male vs Female Buyers')
plt.xlabel('Buyers')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Insights -
#
# The number of female buyers is more than the male buyers participated in the sale.

# %% [markdown]
# 2.Representation of Buyers Gender using the Multiple Bar graph

# %%
data2=pd.DataFrame(data[['Make','Buyer Gender']].value_counts().to_frame())
data2=data2.head(9)
data2
# Out:
#                           0
# Make      Buyer Gender
# Ford      Female        444
#           Male          420
# Chevrolet Male          403
#           Female        397
# Dodge     Female        251
#           Male          249
# Toyota    Female        234
# GMC       Male          232
#           Female        222

# %%
data2=data2.drop(['Toyota'])
data2
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#                           0
# Make      Buyer Gender
# Ford      Female        444
#           Male          420
# Chevrolet Male          403
#           Female        397
# Dodge     Female        251
#           Male          249
# GMC       Male          232
#           Female        222

# %%
w=0.4
X=['Ford','Chevrolet','Dodge','GMC']
Male=[420,403,249,232]
Female=[444,397,251,222]
bar1=np.arange(len(X))
plt.bar(bar1,Male,w,label="Male")
bar2=[i+w for i in bar1]
plt.bar(bar2,Female,w,label="Female")
plt.xticks(bar1+w/2,X)
plt.xlabel('Make')
plt.ylabel('No.of Buyers')
plt.title('Buyers Gender')
plt.legend()

# %% [markdown]
# Insights-
#
# 1.The difference between the number of male buyers and female buyers who participated in the sale is maximum in the case
# of Ford among the four samples considered.
#
# 2.The difference between the number of male buyers and female buyers who participated in the sale is minimum in the case
# of Dodge among the four samples considered.

# %% [markdown]
# # 4. Find the top 5 cars based on their sales price.

# %% [markdown]
# 1.#using nlargest()

# %%
top_cars=data.groupby(by='Make')['Sale Price'].nlargest(5)
top_cars
# Out:
# Make
# Acura  5474    99303.08
#        7047    99129.00
#        8228    98983.21
#        7849    98464.04
#        4513    97865.83
#                  ...
# Volvo  2533    99382.92
#        5036    98355.95
#        6404    98068.48
#        1591    96950.18
#        6673    96878.08
# Name: Sale Price, Length: 323, dtype: float64

# %%
pd.set_option('max_rows',None)
top_cars
# Out:
# Make
# Acura            99303.08
# Alfa Romeo       90078.87
# Aptera           83016.73
# Aston Martin     99506.62
# Audi             99991.91
# Austin           95199.24
# BMW              99814.48
# Bentley          98315.87
# Bugatti          49160.67
# Buick            99359.08
# Cadillac         99334.92
# Chevrolet        99932.74
# Chrysler         99656.21
# Citroën          92752.02
# Corbin           13270.10
# Daewoo           98725.42
# Daihatsu         59994.33
# Dodge            99908.29
# Eagle            92441.07
# Ferrari          99795.06
# Fiat             48420.14
# Fillmore         41778.53
# Ford             99837.56
# GMC              99744.76
# Geo              81083.54
# Hillman          99857.73
# Holden           99763.83
# Honda            99943.77
# Hummer           98961.70
# Hyundai          99072.86
# Infiniti         99764.34
# Isuzu            99909.20
# Jaguar           99599.61
# Jeep             93454.97
# Jensen           83364.31
# Kia              98709.71
# Lamborghini      99966.56
# Land Rover       99601.33
# Lexus            99983.38
# Lincoln          99558.38
# Lotus            99486.84
# MG               70360.36
# MINI             98376.10
# Maserati         99947.94
# Maybach          99850.75
# Mazda            99978.17
# Mercedes-Benz    99834.82
# Mercury          99756.70
# Merkur           76790.84
# Mitsubishi       99610.79
# Morgan           96386.39
# Nissan           99685.82
# Oldsmobile       98009.82
# Panoz            83492.56
# Peugeot          84748.46
# Plymouth         98806.84
# Pontiac          99841.02
# Porsche          97766.25
# Ram              93532.72
# Rambler          80993.56
# Renault          62964.69
# Rolls-Royce      94320.21
# Saab             99305.50
# Saturn           99771.37
# Scion            95681.78
# Shelby           58660.92
# Smart            84884.02
# Spyker           83554.58
# Studebaker       74504.17
# Subaru           99564.16
# Suzuki           99704.14
# Tesla            84174.23
# Toyota           99963.94
# Volkswagen       99997.65
# Volvo            99382.92
# Name: Sale Price, dtype: float64

# %% [markdown]
# Insights-
#
# The top five cars based on their sale price are : Acura,Alfa Romeo,Aptera,Aston Martin,Audi.

# %% [markdown]
# 2.using max()

# %%
top_cars=data.groupby(by='Make')['Sale Price'].max()
top_cars
# Out:
# Make
# Acura           99303.08
# Alfa Romeo      90078.87
# Aptera          83016.73
# Aston Martin    99506.62
# Audi            99991.91
#                   ...
# Suzuki          99704.14
# Tesla           84174.23
# Toyota          99963.94
# Volkswagen      99997.65
# Volvo           99382.92
# Name: Sale Price, Length: 75, dtype: float64

# %% [markdown]
# Insights-
#
# The top five cars based on their sale price are : Acura,Alfa Romeo,Aptera,Aston Martin,Audi.

# %% [markdown]
# # 5. Find the least 5 cars based on their Resell price.

# %% [markdown]
# 1.Using min()

# %%
least_cars=data.groupby(by='Make')['Resell Price'].min()
least_cars
# Out:
# Make
# Acura            2092.06
# Alfa Romeo       4960.23
# Aptera           8716.20
# Aston Martin     2231.80
# Audi             2604.70
#                   ...
# Suzuki           2155.37
# Tesla           13135.51
# Toyota           2126.92
# Volkswagen       2157.70
# Volvo            2549.58
# Name: Resell Price, Length: 75, dtype: float64

# %% [markdown]
# Insights-
#
# The least five cars based on their resell price are : Acura,Alfa Romeo,Aptera,Aston Martin,Audi.

# %% [markdown]
# 2.Using nsmallest()

# %%
least_cars=data.groupby(by='Make')['Resell Price'].nsmallest(5)
least_cars
# Out:
# Make
# Acura          2958     2092.06
#                4863     2139.11
#                6795     2209.56
#                7345     3191.43
#                5643     3221.68
# Alfa Romeo     6183     4960.23
#                3078    12752.81
#                3457    17596.65
#                4151    29719.30
#                7876    39427.71
# Aptera         2252     8716.20
#                6606    31943.94
#                8651    46366.34
#                2401    47503.21
# Aston Martin   1533     2231.80
#                7696     2274.18
#                6555     2753.05
#                191      3540.51
#                5872     3654.36
# Audi           9570     2604.70
#                7360     2694.57
#                5377     2823.28
#                4431     3071.06
#                6365     3230.67
# Austin         4670    10823.78
#                8241    18275.53
#                717     24758.21
#                2788    41001.20
#                3133    44141.52
# BMW            4475     2032.28
#                1182     2084.61
#                9940     2179.26
#                2726     2253.04
#                39       2386.28
# Bentley        846      5882.23
#                6773     6097.05
#                9961     8170.22
#                9092     8836.10
#                223     10736.67
# Bugatti        7328     8880.42
#                3230    22344.86
#                1301    48326.94
# Buick          9887     2207.24
#                3520     2477.14
#                954      2541.28
#                409      2777.18
#                6335     2795.53
# Cadillac       8781     2148.19
#                8855     2205.34
#                3541     2243.95
#                133      2409.83
#                1740     2579.38
# Chevrolet      2446     2000.84
#                5503     2051.48
#                2018     2096.78
#                4532     2150.28
#                5003     2185.58
# Chrysler       3984     2333.95
#                4056     2385.16
#                9017     2405.02
#                5571     2447.01
#                592      2550.23
# Citroën        5900     8104.89
#                1190    15023.24
#                3503    31501.96
#                7022    32238.50
#                4124    35195.25
# Corbin         2434    23699.97
# Daewoo         8873     3598.10
#                3872     6891.67
#                5449     9290.25
#                4277     9875.79
#                2584    10159.85
# Daihatsu       812      6679.71
#                2753    28357.95
# Dodge          9249     2120.15
#                1523     2503.87
#                9055     2542.62
#                4857     2686.20
#                4879     2716.16
# Eagle          1403     2347.88
#                8833     2978.38
#                7453     3735.12
#                9876     3787.35
#                4006     8876.08
# Ferrari        1929     2160.65
#                6422     3295.21
#                2381     6162.70
#                9735     7443.16
#                6502     9247.75
# Fiat           9732    31807.95
#                946     36026.48
# Fillmore       8625     3175.68
#                3237    35288.33
# Ford           8680     2043.44
#                5639     2053.52
#                5455     2100.97
#                5207     2155.91
#                608      2250.46
# GMC            4933     2005.44
#                5345     2042.41
#                4790     2062.61
#                5990     2105.69
#                6937     2283.71
# Geo            9666     6464.02
#                2075     9191.00
#                4931    12025.11
#                1458    12339.10
#                399     15312.85
# Hillman        502     46868.52
# Holden         988      2918.06
#                7877     9906.48
#                4461    12054.43
#                7327    26384.07
#                6373    39945.55
# Honda          3172     2038.14
#                4624     2354.20
#                6279     2408.02
#                2245     2445.05
#                2846     2549.78
# Hummer         3246     2593.52
#                3781     3601.17
#                9718     5266.77
#                3770     7080.87
#                942      7974.47
# Hyundai        5197     2021.75
#                421      2168.83
#                6993     2536.63
#                8092     2660.52
#                3990     2946.56
# Infiniti       5869     2017.83
#                3490     2369.00
#                8582     2509.84
#                9104     2826.63
#                7714     2883.38
# Isuzu          341      2993.98
#                7552     5897.76
#                5366     7108.64
#                7023     7332.23
#                1198     7686.58
# Jaguar         566      2014.09
#                2781     2085.01
#                5691     2942.96
#                5926     4146.97
#                3398     4340.69
# Jeep           4058     2063.00
#                1149     3247.00
#                6921     4072.95
#                675      4607.86
#                4651     5277.51
# Jensen         1805    44581.43
# Kia            4565     2303.26
#                9187     2608.89
#                7921     3100.37
#                3397     3456.14
#                6382     3641.04
# Lamborghini    5838     2124.01
#                5777     2918.83
#                2610     3398.33
#                9258     3859.76
#                9191     4472.00
# Land Rover     2629     2189.36
#                8150     2800.29
#                9819     3134.05
#                9776     3603.06
#                2749     3813.07
# Lexus          735      2220.11
#                3441     2305.04
#                7935     2363.51
#                9006     2420.88
#                5340     2827.51
# Lincoln        3968     2214.79
#                9281     2337.34
#                8215     2450.58
#                8464     2623.02
#                1229     2708.20
# Lotus          6860     2178.41
#                7617     2197.22
#                4748     2327.43
#                5200     2565.55
#                8378     3490.73
# MG             4266     8378.72
# MINI           4194     2477.78
#                1225     2994.74
#                7950     4321.62
#                3712     4474.55
#                8671     5880.43
# Maserati       9472     4443.25
#                7176     5132.18
#                7310     6118.33
#                3538     7295.01
#                457      7440.73
# Maybach        8475     2358.04
#                3885     3275.82
#                9771     8042.96
#                446      8480.66
#                196      9483.17
# Mazda          1841     2137.61
#                3779     2184.17
#                5640     2265.81
#                6052     2620.88
#                3126     2910.09
# Mercedes-Benz  9399     2145.99
#                8900     2507.79
#                1824     2529.39
#                9782     2618.26
#                3090     2783.16
# Mercury        6619     2408.84
#                5024     2491.95
#                9997     2731.25
#                7860     3340.27
#                9088     3410.92
# Merkur         5814    28524.07
#                3243    30442.44
#                3685    42272.61
# Mitsubishi     2538     2017.24
#                6396     2020.89
#                3427     2166.92
#                2032     2198.07
#                2093     2257.14
# Morgan         7793     6500.19
#                4747    11438.35
#                1976    18894.33
#                2137    33929.02
#                9790    34528.95
# Nissan         8837     2055.63
#                3177     2624.39
#                135      3131.75
#                9572     3495.66
#                7230     3523.34
# Oldsmobile     9049     2202.01
#                1178     2244.67
#                9613     2818.40
#                5116     3143.54
#                3136     4669.19
# Panoz          6053     9868.12
#                7624    20366.42
# Peugeot        9173    34021.10
#                6246    44103.12
# Plymouth       7003     3261.65
#                6226     4392.12
#                6884     4635.05
#                3932     5267.76
#                4043     5285.44
# Pontiac        8550     2030.79
#                6788     2092.11
#                8998     2107.82
#                4908     2263.76
#                953      2316.79
# Porsche        5967     2408.17
#                4657     3883.21
#                1637     4057.80
#                5058     4246.97
#                9974     4633.66
# Ram            7976     4041.91
#                5738     4577.95
#                1295     4729.20
#                3022     9085.84
#                8925     9264.67
# Rambler        7307    27386.60
#                6182    45548.96
# Renault        5278    44274.07
# Rolls-Royce    376      6127.62
#                4543     9504.64
#                6767    10080.47
#                1201    18075.41
#                6764    18290.45
# Saab           531      2216.02
#                7248     2279.34
#                7186     3059.96
#                4566     3177.37
#                9809     3237.51
# Saturn         9096     3151.88
#                4310     4216.74
#                4242     4818.48
#                6011     7532.66
#                2774     7854.58
# Scion          3340     2486.67
#                483      3144.16
#                8514     3554.14
#                4118     4994.36
#                1305     5444.72
# Shelby         5096    28690.66
# Smart          4182     2288.16
#                9721    27131.36
#                1517    27568.55
# Spyker         9229     2590.27
#                1288     5740.23
#                5905     5847.64
#                6786     6480.99
#                4775    24981.67
# Studebaker     3552    16924.62
#                7556    17307.80
#                9504    19581.70
#                5258    20975.01
#                9530    43860.97
# Subaru         1466     2353.47
#                5286     2646.82
#                3165     2869.99
#                6498     3044.65
#                2113     4244.81
# Suzuki         4365     2155.37
#                4504     2402.25
#                2298     2672.38
#                676      3561.39
#                5010     3891.35
# Tesla          5074    13135.51
#                7246    21190.81
# Toyota         7634     2126.92
#                4384     2143.15
#                1673     2177.69
#                6319     2357.42
#                5779     2438.40
# Volkswagen     2275     2157.70
#                913      2358.71
#                6557     2514.06
#                1760     2661.08
#                3627     2809.06
# Volvo          5851     2549.58
#                3362     2683.60
#                6567     2833.66
#                8562     3019.37
#                8761     3081.57
# Name: Resell Price, dtype: float64

# %% [markdown]
# Insights-
#
# The least five cars based on their resell price are : Acura,Alfa Romeo,Aptera,Aston Martin,Audi.
